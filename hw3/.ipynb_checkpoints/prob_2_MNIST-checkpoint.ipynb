# %%
import numpy as np
from neural_net import NeuralNet
# %load_ext autoreload
# %autoreload 2
import scipy.io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = "mnist"
nn = NeuralNet.fromMAT(filename, varname = 'tr', type="train", lam=10, M=300)
print np.shape(nn.T)
nn.train(stepSize=5e-5, maxFunctionCalls=5000, varname='tr')
# Out:
# (6, 1000)
# Actual data
# can only plot data if x is two dimensional
# It took 4.60147857666e-05 seconds to plot original data.
# using standard gradient descent
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-29ac94bac0b6> in <module>()
#       2 nn = NeuralNet.fromMAT(filename, varname = 'tr', type="train", lam=10, M=300)
#       3 print np.shape(nn.T)
# ----> 4 nn.train(stepSize=1e-4, maxFunctionCalls=3000, varname='tr')
#
# /Users/pflomacpro/Desktop/Classes/6.867/Machine-Learning-6.867-homework/hw3/neural_net.pyc in train(self, w_list_initial, useSGD, stepSize, maxFunctionCalls, verbose, tol, storeIterValues, varname)
#     366         else:
#     367             print "using standard gradient descent"
# --> 368             w_min, f_min, _, _ = gd.computeMin(w_initial, maxFunctionCalls=maxFunctionCalls, storeIterValues=True, printSummary=verbose)
#     369
#     370         if verbose and storeIterValues:
#
# /Users/pflomacpro/Desktop/Classes/6.867/Machine-Learning-6.867-homework/hw1/gradient_descent.pyc in computeMin(self, x_initial, maxFunctionCalls, useGradientCriterion, storeIterValues, storeIterX, printSummary, tol)
#      97         while(np.abs(eps) > tol):
#      98             self.numIterations += 1
# ---> 99             (x_current, f_current) = self.gradDescentUpdate(x_current)
#     100             eps = f_current - f_old
#     101             f_old = f_current
#
# /Users/pflomacpro/Desktop/Classes/6.867/Machine-Learning-6.867-homework/hw1/gradient_descent.pyc in gradDescentUpdate(self, x)
#     157                 x_new.append(x[idx] - self.stepSize*grad[idx])
#     158
# --> 159             f_new = self.evalF(x_new)
#     160
#     161         else:
#
# /Users/pflomacpro/Desktop/Classes/6.867/Machine-Learning-6.867-homework/hw1/gradient_descent.pyc in evalF(self, x)
#      37     def evalF(self,x):
#      38         self.numFunctionCalls += 1
# ---> 39         return self.f(x)
#      40
#      41     def evalFOnTrainingData(self, idx):
#
# /Users/pflomacpro/Desktop/Classes/6.867/Machine-Learning-6.867-homework/hw3/neural_net.pyc in <lambda>(w_list)
#     215             lam = self.lam
#     216
# --> 217         f = lambda w_list: self.evalCost(lam, w_list=w_list)
#     218         grad = lambda w_list: self.evalDerivs(w_list, lam=lam)
#     219         gd = GradientDescent(f, grad=grad)
#
# /Users/pflomacpro/Desktop/Classes/6.867/Machine-Learning-6.867-homework/hw3/neural_net.pyc in evalCost(self, lam, w_list, skipForwardProp)
#     199         # forwardProp'd with the weights they want
#     200         if not skipForwardProp:
# --> 201             self.forwardProp(xsample, w_list=w_list)
#     202
#     203
#
# /Users/pflomacpro/Desktop/Classes/6.867/Machine-Learning-6.867-homework/hw3/neural_net.pyc in forwardProp(self, xsample, w_list)
#     101         n = np.shape(xsample)[1]
#     102         # compute activations from weights, should be size M x n
# --> 103         self.a_hidden = np.dot(W1,xsample)
#     104
#     105         # compute output of each unit via activation function
#
# KeyboardInterrupt:

# %%
nn.test(varname='te')
nn.validate(varname='va')

# %%
M = np.linspace(25,300,(325-25)*1.0/25.0)
print M

trainCER = M * 1.0
testCER = M * 1.0
validateCER = M * 1.0

trainTime = M * 0.0

Trials = 3

for i in range(len(M)):
    for j in range(Trials):
        m = M[i]
        filename = "mnist"
        nn = NeuralNet.fromMAT(filename, varname = 'tr', type="train", lam=0, M=m)

        nn.train(stepSize=5e-5, maxFunctionCalls=5000, varname='tr', verbose=False)
        if (nn.missclassifiedRate < trainCER[i]):
            trainCER[i] = nn.missclassifiedRate
        
        trainTime[i] += nn.trainingTime

        nn.test(varname='te', verbose=False)
        if (nn.missclassifiedRate < testCER[i]):
            testCER[i] = nn.missclassifiedRate

        nn.validate(varname='va', verbose=False)
        if (nn.missclassifiedRate < validateCER[i]):
            validateCER[i] = nn.missclassifiedRate
# Out:
# [  25.   50.   75.  100.  125.  150.  175.  200.  225.  250.  275.  300.]
# using standard gradient descent
# It took 28.6825590134 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 248
# missclassification rate  = 0.248
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 109
# missclassification rate  = 0.218
# It took 0.025367975235 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 107
# missclassification rate  = 0.214
# It took 0.0291628837585 seconds to validate.
# using standard gradient descent
# It took 35.2124919891 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 240
# missclassification rate  = 0.24
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 95
# missclassification rate  = 0.19
# It took 0.0219368934631 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 113
# missclassification rate  = 0.226
# It took 0.0315020084381 seconds to validate.
# using standard gradient descent
# It took 31.0545880795 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 244
# missclassification rate  = 0.244
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 125
# missclassification rate  = 0.25
# It took 0.0229530334473 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 100
# missclassification rate  = 0.2
# It took 0.0237309932709 seconds to validate.
# using standard gradient descent
# It took 47.2145118713 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 135
# missclassification rate  = 0.135
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 61
# missclassification rate  = 0.122
# It took 0.0236439704895 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 69
# missclassification rate  = 0.138
# It took 0.0236570835114 seconds to validate.
# using standard gradient descent
# It took 47.9233019352 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 137
# missclassification rate  = 0.137
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 77
# missclassification rate  = 0.154
# It took 0.0273230075836 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 59
# missclassification rate  = 0.118
# It took 0.0274918079376 seconds to validate.
# using standard gradient descent
# It took 47.6933679581 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 138
# missclassification rate  = 0.138
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 66
# missclassification rate  = 0.132
# It took 0.0262269973755 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 75
# missclassification rate  = 0.15
# It took 0.0275120735168 seconds to validate.
# using standard gradient descent
# It took 62.4940760136 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 111
# missclassification rate  = 0.111
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 65
# missclassification rate  = 0.13
# It took 0.0267388820648 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 55
# missclassification rate  = 0.11
# It took 0.0265748500824 seconds to validate.
# using standard gradient descent
# It took 61.9080998898 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 112
# missclassification rate  = 0.112
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 67
# missclassification rate  = 0.134
# It took 0.0221090316772 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 59
# missclassification rate  = 0.118
# It took 0.0235769748688 seconds to validate.
# using standard gradient descent
# It took 62.1123051643 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 104
# missclassification rate  = 0.104
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 57
# missclassification rate  = 0.114
# It took 0.0243270397186 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 57
# missclassification rate  = 0.114
# It took 0.0258750915527 seconds to validate.
# using standard gradient descent
# It took 63.0594680309 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 89
# missclassification rate  = 0.089
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 57
# missclassification rate  = 0.114
# It took 0.0234470367432 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 55
# missclassification rate  = 0.11
# It took 0.024759054184 seconds to validate.
# using standard gradient descent
# It took 61.67314291 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 86
# missclassification rate  = 0.086
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 49
# missclassification rate  = 0.098
# It took 0.0258619785309 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 45
# missclassification rate  = 0.09
# It took 0.026468038559 seconds to validate.
# using standard gradient descent
# It took 62.7484009266 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 93
# missclassification rate  = 0.093
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 49
# missclassification rate  = 0.098
# It took 0.0244371891022 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 47
# missclassification rate  = 0.094
# It took 0.0274648666382 seconds to validate.
# using standard gradient descent
# It took 82.5866701603 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 69
# missclassification rate  = 0.069
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 46
# missclassification rate  = 0.092
# It took 0.0253250598907 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 46
# missclassification rate  = 0.092
# It took 0.0249300003052 seconds to validate.
# using standard gradient descent
# It took 81.5214819908 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 70
# missclassification rate  = 0.07
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 49
# missclassification rate  = 0.098
# It took 0.0240960121155 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 44
# missclassification rate  = 0.088
# It took 0.0241270065308 seconds to validate.
# using standard gradient descent
# It took 82.9200539589 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 69
# missclassification rate  = 0.069
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 46
# missclassification rate  = 0.092
# It took 0.023745059967 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 42
# missclassification rate  = 0.084
# It took 0.0232849121094 seconds to validate.
# using standard gradient descent
# It took 107.408947945 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 58
# missclassification rate  = 0.058
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 39
# missclassification rate  = 0.078
# It took 0.0284900665283 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 42
# missclassification rate  = 0.084
# It took 0.0257341861725 seconds to validate.
# using standard gradient descent
# It took 105.041593075 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 62
# missclassification rate  = 0.062
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 46
# missclassification rate  = 0.092
# It took 0.0245921611786 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 38
# missclassification rate  = 0.076
# It took 0.025995016098 seconds to validate.
# using standard gradient descent
# It took 106.176277876 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 61
# missclassification rate  = 0.061
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 50
# missclassification rate  = 0.1
# It took 0.0241589546204 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 44
# missclassification rate  = 0.088
# It took 0.0256969928741 seconds to validate.
# using standard gradient descent
# It took 127.795404196 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 57
# missclassification rate  = 0.057
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 53
# missclassification rate  = 0.106
# It took 0.0263719558716 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 49
# missclassification rate  = 0.098
# It took 0.0269939899445 seconds to validate.
# using standard gradient descent
# It took 130.497546911 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 67
# missclassification rate  = 0.067
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 47
# missclassification rate  = 0.094
# It took 0.0271129608154 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 39
# missclassification rate  = 0.078
# It took 0.0301361083984 seconds to validate.
# using standard gradient descent
# It took 132.348746061 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 61
# missclassification rate  = 0.061
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 48
# missclassification rate  = 0.096
# It took 0.0297949314117 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 44
# missclassification rate  = 0.088
# It took 0.0328438282013 seconds to validate.
# using standard gradient descent
# It took 125.651248932 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 47
# missclassification rate  = 0.047
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 40
# missclassification rate  = 0.08
# It took 0.0258679389954 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 39
# missclassification rate  = 0.078
# It took 0.0257818698883 seconds to validate.
# using standard gradient descent
# It took 126.574670076 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 56
# missclassification rate  = 0.056
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 40
# missclassification rate  = 0.08
# It took 0.0269370079041 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 42
# missclassification rate  = 0.084
# It took 0.0273509025574 seconds to validate.
# using standard gradient descent
# It took 130.670073986 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 48
# missclassification rate  = 0.048
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 38
# missclassification rate  = 0.076
# It took 0.0367000102997 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 41
# missclassification rate  = 0.082
# It took 0.0348739624023 seconds to validate.
# using standard gradient descent
# It took 145.902424097 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 45
# missclassification rate  = 0.045
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 42
# missclassification rate  = 0.084
# It took 0.0268049240112 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 39
# missclassification rate  = 0.078
# It took 0.0276391506195 seconds to validate.
# using standard gradient descent
# It took 140.452877045 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 48
# missclassification rate  = 0.048
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 42
# missclassification rate  = 0.084
# It took 0.0283010005951 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 38
# missclassification rate  = 0.076
# It took 0.0268769264221 seconds to validate.
# using standard gradient descent
# It took 170.811038017 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 53
# missclassification rate  = 0.053
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 36
# missclassification rate  = 0.072
# It took 0.0313541889191 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 39
# missclassification rate  = 0.078
# It took 0.029580116272 seconds to validate.
# using standard gradient descent
# It took 201.999523163 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 44
# missclassification rate  = 0.044
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 44
# missclassification rate  = 0.088
# It took 0.0293447971344 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 46
# missclassification rate  = 0.092
# It took 0.0332880020142 seconds to validate.
# using standard gradient descent
# It took 205.366247892 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 43
# missclassification rate  = 0.043
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 37
# missclassification rate  = 0.074
# It took 0.0278980731964 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 43
# missclassification rate  = 0.086
# It took 0.0302531719208 seconds to validate.
# using standard gradient descent
# It took 166.833546877 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 44
# missclassification rate  = 0.044
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 37
# missclassification rate  = 0.074
# It took 0.0280079841614 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 42
# missclassification rate  = 0.084
# It took 0.0331161022186 seconds to validate.
# using standard gradient descent
# It took 218.028650045 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 40
# missclassification rate  = 0.04
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 38
# missclassification rate  = 0.076
# It took 0.0323741436005 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 34
# missclassification rate  = 0.068
# It took 0.0314500331879 seconds to validate.
# using standard gradient descent
# It took 189.748035908 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 40
# missclassification rate  = 0.04
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 31
# missclassification rate  = 0.062
# It took 0.0299189090729 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 35
# missclassification rate  = 0.07
# It took 0.0302500724792 seconds to validate.
# using standard gradient descent
# It took 184.596868038 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 44
# missclassification rate  = 0.044
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 40
# missclassification rate  = 0.08
# It took 0.0286920070648 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 39
# missclassification rate  = 0.078
# It took 0.0284721851349 seconds to validate.
# using standard gradient descent
# It took 184.15453887 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 42
# missclassification rate  = 0.042
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 34
# missclassification rate  = 0.068
# It took 0.0297298431396 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 39
# missclassification rate  = 0.078
# It took 0.0280508995056 seconds to validate.
# using standard gradient descent
# It took 184.200488091 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 40
# missclassification rate  = 0.04
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 42
# missclassification rate  = 0.084
# It took 0.0242600440979 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 38
# missclassification rate  = 0.076
# It took 0.0292320251465 seconds to validate.
# using standard gradient descent
# It took 183.899573088 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 35
# missclassification rate  = 0.035
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 41
# missclassification rate  = 0.082
# It took 0.0258629322052 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 40
# missclassification rate  = 0.08
# It took 0.0292830467224 seconds to validate.

# %%
nn.missclassifiedRate
print trainCER
# Out:
# [ 0.24   0.135  0.104  0.086  0.069  0.058  0.057  0.047  0.045  0.043
#   0.04   0.035]

# %%
print "Training CER vs. M (number of hidden nodes)"    
plt.plot(M, trainCER, 'red', label = 'train')

print "Test CER vs. M (number of hidden nodes)"    
plt.plot(M, testCER, 'green', label=' test')

print "Validation CER vs. M (number of hidden nodes)"    
plt.plot(M, validateCER, 'blue', label=" val")

plt.xlabel(' # hidden nodes')
plt.ylabel('Classification Error Rate')
plt.legend(loc='best')
plt.show()


plt.show()

print "Training time vs. M (number of hidden nodes)"    
plt.xlabel(' # hidden nodes')
plt.ylabel('Training Time')
plt.plot(M, trainTime, 'black')
plt.show()
# Out:
# Training CER vs. M (number of hidden nodes)
# Test CER vs. M (number of hidden nodes)
# Validation CER vs. M (number of hidden nodes)
# Training time vs. M (number of hidden nodes)

# %%
M = np.linspace(0,5,10)
print M

trainCER = M * 1.0
testCER = M * 1.0
validateCER = M * 1.0

trainTime = M * 0.0

Trials = 1

for i in range(len(M)):
    for j in range(Trials):
        m = M[i]
        filename = "mnist"
        nn = NeuralNet.fromMAT(filename, varname = 'tr', type="train", lam=m, M=150)

        nn.train(stepSize=5e-5, maxFunctionCalls=5000, varname='tr', verbose=False)
        if (nn.missclassifiedRate < trainCER[i]):
            trainCER[i] = nn.missclassifiedRate
        
        trainTime[i] += nn.trainingTime

        nn.test(varname='te', verbose=False)
        if (nn.missclassifiedRate < testCER[i]):
            testCER[i] = nn.missclassifiedRate

        nn.validate(varname='va', verbose=False)
        if (nn.missclassifiedRate < validateCER[i]):
            validateCER[i] = nn.missclassifiedRate
# Out:
# [ 0.          0.55555556  1.11111111  1.66666667  2.22222222  2.77777778
#   3.33333333  3.88888889  4.44444444  5.        ]
# using standard gradient descent
# It took 103.453661203 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 53
# missclassification rate  = 0.053
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 44
# missclassification rate  = 0.088
# It took 0.0271680355072 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 46
# missclassification rate  = 0.092
# It took 0.0264730453491 seconds to validate.
# using standard gradient descent
# It took 112.088439941 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 73
# missclassification rate  = 0.073
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 46
# missclassification rate  = 0.092
# It took 0.027951002121 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 50
# missclassification rate  = 0.1
# It took 0.0290379524231 seconds to validate.
# using standard gradient descent
# It took 91.87915802 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 93
# missclassification rate  = 0.093
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 52
# missclassification rate  = 0.104
# It took 0.0290160179138 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 48
# missclassification rate  = 0.096
# It took 0.0279848575592 seconds to validate.
# using standard gradient descent
# It took 65.6899740696 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 104
# missclassification rate  = 0.104
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 62
# missclassification rate  = 0.124
# It took 0.0314891338348 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 57
# missclassification rate  = 0.114
# It took 0.0296409130096 seconds to validate.
# using standard gradient descent
# It took 51.5027339458 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 116
# missclassification rate  = 0.116
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 52
# missclassification rate  = 0.104
# It took 0.0295929908752 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 41
# missclassification rate  = 0.082
# It took 0.028990983963 seconds to validate.
# using standard gradient descent
# It took 40.3203849792 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 108
# missclassification rate  = 0.108
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 59
# missclassification rate  = 0.118
# It took 0.0272459983826 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 55
# missclassification rate  = 0.11
# It took 0.0281639099121 seconds to validate.
# using standard gradient descent
# It took 35.8189721107 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 130
# missclassification rate  = 0.13
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 64
# missclassification rate  = 0.128
# It took 0.0273561477661 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 54
# missclassification rate  = 0.108
# It took 0.0331928730011 seconds to validate.
# using standard gradient descent
# It took 30.3816781044 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 127
# missclassification rate  = 0.127
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 68
# missclassification rate  = 0.136
# It took 0.0261240005493 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 67
# missclassification rate  = 0.134
# It took 0.0270020961761 seconds to validate.
# using standard gradient descent
# It took 26.9148440361 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 126
# missclassification rate  = 0.126
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 56
# missclassification rate  = 0.112
# It took 0.0296988487244 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 53
# missclassification rate  = 0.106
# It took 0.0257618427277 seconds to validate.
# using standard gradient descent
# It took 109.103801012 seconds to train.
# 1000
# self.correctlyClassified shape: (1000,)
# number of entries missclassified = 287
# missclassification rate  = 0.287
# ### TEST DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 147
# missclassification rate  = 0.294
# It took 0.0258529186249 seconds to test.
# ### VALIDATION DATASET ###
# 500
# self.correctlyClassified shape: (500,)
# number of entries missclassified = 127
# missclassification rate  = 0.254
# It took 0.0262069702148 seconds to validate.

# %%
print "Training CER vs. M (number of hidden nodes)"    
plt.plot(M[1:], trainCER[1:], 'red', label = 'train')

print "Test CER vs. M (number of hidden nodes)"    
plt.plot(M[1:], testCER[1:], 'green', label=' test')

print "Validation CER vs. M (number of hidden nodes)"    
plt.plot(M[1:], validateCER[1:], 'blue', label=" val")

plt.xlabel(' lambda')
plt.ylabel('Classification Error Rate')
plt.legend(loc='best')
plt.show()


plt.show()

print "Training time vs. M (number of hidden nodes)"    
plt.xlabel(' lambda')
plt.ylabel('Training Time')
plt.plot(M[1:], trainTime[1:], 'black')
plt.show()
# Out:
# Training CER vs. M (number of hidden nodes)
# Test CER vs. M (number of hidden nodes)
# Validation CER vs. M (number of hidden nodes)
# Training time vs. M (number of hidden nodes)
