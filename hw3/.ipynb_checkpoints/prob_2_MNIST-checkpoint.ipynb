# %%
import numpy as np
from neural_net import NeuralNet
# %load_ext autoreload
# %autoreload 2
import scipy.io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = "mnist"
nn = NeuralNet.fromMAT(filename, varname = 'tr', type="train", lam=0, M=20)
nn.train(stepSize=1e-7, maxFunctionCalls=300)
# Out:
# Actual data
# can only plot data if x is two dimensional
# It took 4.2200088501e-05 seconds to plot original data.
# WARNING: hit maximum number of function calls
#
# --- Minimization Summary ---
# f_min is = -168.549876691
# achieved tolerance = -0.000613098394098
# numFunctionCalls = 300
# ----------------------------
# It took 20.8424739838 seconds to train.
# Neural net classifier
# It took 0.219830989838 seconds to plot classification predictions.
# number of entries missclassified = 835
# missclassification rate  = 0.835

# %%
nn.test(varname='te')
# Out:
# ### TEST DATASET ###
# number of entries missclassified = 413
# missclassification rate  = 0.826
# It took 0.179306983948 seconds to test.

# %%
nn.validate(varname='va')
# Out:
# ### VALIDATION DATASET ###
# number of entries missclassified = 411
# missclassification rate  = 0.822
# It took 0.181889057159 seconds to validate.
