# %%
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

file = open('storedReward.txt', 'r')
storedReward = pickle.load(file)

plt.plot(storedReward)
plt.show()

# %%
file = open('storedTheta.txt', 'r')
storedTheta = pickle.load(file)


plt.plot(storedTheta[0])
plt.plot(storedTheta[-1])
plt.show()

# %%
A = 10

if A is not None:
    print "hey"
# Out:
# hey
