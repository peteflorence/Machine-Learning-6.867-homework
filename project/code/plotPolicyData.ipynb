# %%
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

file = open('storedReward.txt', 'r')
storedReward = pickle.load(file)

# plt.figure(num=None, figsize=(10, 4), dpi=80, facecolor='w', edgecolor='k')
# plt.title('discounted reward')
# plt.plot(storedRew|ard, '.')
# plt.xlabel('run #')
# plt.ylabel('episode duration (# of dt = 0.05 time steps)')
# plt.show()


file = open('storedDuration.txt', 'r')
storedDuration = pickle.load(file)

# plt.figure(num=None, figsize=(10, 4), dpi=80, facecolor='w', edgecolor='k')
# plt.plot(storedDuration, '.')
# plt.ylim([0,1000])
# plt.xlabel('run #')
# plt.ylabel('episode duration (# of dt = 0.05 time steps)')
# plt.show()


f, axarr = plt.subplots(2, sharex=True, figsize=(10,8))
axarr[0].plot(storedDuration, '.')
#axarr[0].axis([0, len(storedDuration), 0, 5000]) 
axarr[0].set_title('Initialized from Okay Parameters')
axarr[0].set_ylabel('episode duration (# steps, dt = 0.05)')
axarr[1].plot(storedReward, '.')
axarr[1].set_ylabel('discounted reward')
axarr[1].set_xlabel('run #')

f.show()

# %%
file = open('storedTheta.txt', 'r')
storedTheta = pickle.load(file)

print len(storedTheta)


plt.figure(num=None, figsize=(8, 5), dpi=80, facecolor='w', edgecolor='k')
plt.title('Weights Learned from Gradient-descent Policy Search $(\Theta_{left})$')
plt.plot(storedTheta[0], label="initial weights")
plt.plot(storedTheta[-1], label="final learned weights")
plt.legend(loc='best')
plt.xlabel('$(\Theta_i)$')
plt.show()
# Out:
# 546
