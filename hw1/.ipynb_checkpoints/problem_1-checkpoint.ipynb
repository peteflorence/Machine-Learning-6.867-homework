# %% [markdown]
# # Testing Environment for Homework 1

# %%
# Global setup
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# ## 1. Implement Gradient Descent

# %% [markdown]
# 1) Implement a basic gradient descent procedure to minimize scalar functions of a vector argument. Write it generically, so that you can easily specify the objective function and the function to compute the gradient. You should be able to specify the initial guess, the step size and the convergence criterion (a threshold such that the algorithm terminates when the difference in objective function value on two successive steps is below this threshold).

# %%
from gradient_descent import GradientDescent, quad, quadGrad

gd = GradientDescent(quad, quadGrad)

gd.stepSize = 1e-2
gd.tol = 1e-6
x_0 = np.array([1.0, 1.0])
print gd.computeMin(x_0,useGradientCriterion=True)
# Out:
#
# --- Minimization Summary ---
# x_min is = [  4.91528181e-07   4.91528181e-07]
# f_min is = 4.83199906383e-13
# achieved tolerance = 9.83056362965e-07
# numFunctionCalls = 720
# ----------------------------
#
# (array([  4.91528181e-07,   4.91528181e-07]), 4.8319990638341978e-13, 720, 1e-06)

# %%
x_0 = np.array([1.0, 1.0])
print GradientDescent.minimize(quad, x_0, grad=quadGrad)
# Out:
#
# --- Minimization Summary ---
# x_min is = [ 0.03425742  0.03425742]
# f_min is = 0.00234714152513
# achieved tolerance = -9.67792632187e-05
# numFunctionCalls = 168
# ----------------------------
#
# (array([ 0.03425742,  0.03425742]), 0.0023471415251319705, 168, 0.0001)

# %%
gd = GradientDescent(quad, quadGrad)
gd.tol = 1e-6

gd.computeMin(x_0, useGradientCriterion=True, storeIterValues=True)
gd.plotIterValues()
# Out:
#
# --- Minimization Summary ---
# x_min is = [  4.91528181e-07   4.91528181e-07]
# f_min is = 4.83199906383e-13
# achieved tolerance = 9.83056362965e-07
# numFunctionCalls = 720
# ----------------------------

# %% [markdown]
# ##### Testing GradientDescent class
#
# Plot default function stored as instance variable

# %%
gd = GradientDescent(quad, quadGrad)

# Test functions are there
print gd.f
print gd.grad

# Test values for functions
print gd.f(2)
print gd.grad(1)

# Plot functions and overlay gradient
xaxis = np.linspace(-10,10,21)
yaxis_f = np.linspace(0,0,21)
yaxis_grad = np.linspace(0,0,21)

# Wish I could vectorize but this does not work
# yaxis_f = gd.f(xaxis)
# yaxis_grad = gd.grad(xaxis)

for i in range(len(xaxis)):
    yaxis_f[i] = gd.f(xaxis[i])
    yaxis_grad[i] = gd.grad(xaxis[i])
    
print xaxis.shape
print yaxis_f.shape

print 'Function in blue, derivative in red'
plt.plot(xaxis,yaxis_f, color ='blue')
plt.plot(xaxis,yaxis_grad, color='red')
plt.show()
# Out:
# <function quad at 0x116529c08>
# <function quadGrad at 0x11653e0c8>
# 4
# 2
# (21,)
# (21,)
# Function in blue, derivative in red

# %% [markdown]
# 2) Test your gradient descent procedure on some functions whose optimal value you know, e.g. a quadratic bowl or (the negative of) a Gaussian probability density function. Make sure that you try functions of more than one variable and that you try at least one convex function and one very non-convex function with multiple minima. Discuss the effect of the choice of starting guess, the step size, and the convergence criterion on the resulting solution.

# %% [markdown]
# Try one convex function, such as the negative of a Gaussian probability function.

# %%
def negGaussian(x, mu=0, sig=1):
    return -1 * (1/(sig * np.sqrt(2*np.pi))) * np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

gd = GradientDescent(negGaussian)
x_0 = np.array([1.0])

gd.tol = 1e-6
gd.computeMin(x_0,useGradientCriterion=True,maxFunctionCalls=10000,storeIterValues=True)
gd.plotIterValues()
# Out:
# WARNING: hit maximum number of function calls
#
# --- Minimization Summary ---
# x_min is = [ 0.00044915]
# f_min is = [-0.39894224]
# achieved tolerance = 0.000179184495019
# numFunctionCalls = 10001
# ----------------------------

# %% [markdown]
# Try one very non-convex function

# %%
def f(x):
    return x**4 - (x)**3 -(x)**2
def gradf(x):
    return 4*x**3 - 3*x**2 - 2*x

gd = GradientDescent(f,gradf)
x_0 = np.array([1.0])

gd.tol = 1e-6
gd.computeMin(x_0,useGradientCriterion=True,maxFunctionCalls=10000,storeIterValues=True)
gd.plotIterValues()

# Test functions are there
print gd.f
print gd.grad

# Test values for functions
print gd.f(2)
print gd.grad(1)

# Plot functions and overlay gradient
xaxis = np.linspace(-10,10,201)
yaxis_f = np.linspace(0,0,201)
yaxis_grad = np.linspace(0,0,201)

# Wish I could vectorize but this does not work
# yaxis_f = gd.f(xaxis)
# yaxis_grad = gd.grad(xaxis)

for i in range(len(xaxis)):
    yaxis_f[i] = gd.f(xaxis[i])
    yaxis_grad[i] = gd.grad(xaxis[i])
    
print xaxis.shape
print yaxis_f.shape

print 'Function in blue, derivative in red'
plt.plot(xaxis,yaxis_f, color ='blue')
#plt.plot(xaxis,yaxis_grad, color='red')
plt.axis([-2, 2, -2, 3])
plt.show()
# Out:
#
# --- Minimization Summary ---
# x_min is = [ 1.17539041]
# f_min is = [-1.09673456]
# achieved tolerance = 9.30769600505e-07
# numFunctionCalls = 186
# ----------------------------
# <function f at 0x119594050>
# <function gradf at 0x11ab597d0>
# 4
# -1
# (201,)
# (201,)
# Function in blue, derivative in red

# %% [markdown]
# ### Analytcal gradients

# %%
gd = GradientDescent(f,gradf)
gd.stepSize = 1e-2
x_0 = np.array([1.9])
gd.computeMin(x_0, useGradientCriterion=True, storeIterX=True,)

def plotWithDescent(gdObj):
    plt.plot(xaxis,yaxis_f, color ='blue')
    #plt.plot(xaxis,yaxis_grad, color='red')
    numIter = (gdObj.numIterations-1)
    plt.plot(gdObj.iterX[0:numIter], f(gdObj.iterX)[0:numIter], marker='x',color='black')
    plt.scatter(gdObj.iterX[0], f(gdObj.iterX)[0], marker='x', s=100, color='red')
    plt.scatter(gdObj.iterX[numIter], f(gdObj.iterX)[numIter], marker='x', s=100, color='green')
    plt.axis([-2, 2, -2, 3])
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.show()

plotWithDescent(gd)
    
x_0 = np.array([-1.0])
gd.computeMin(x_0, useGradientCriterion=True, storeIterX=True,)

plotWithDescent(gd)

x_0 = np.array([0.0])
gd.computeMin(x_0, useGradientCriterion=True, storeIterX=True,)

plotWithDescent(gd)
# Out:
#
# --- Minimization Summary ---
# x_min is = [ 1.17540341]
# f_min is = [-1.09673456]
# achieved tolerance = 9.69637218273e-05
# numFunctionCalls = 130
# ----------------------------
#
# --- Minimization Summary ---
# x_min is = [-0.4254267]
# f_min is = [-0.07123419]
# achieved tolerance = 9.85454121549e-05
# numFunctionCalls = 312
# ----------------------------
#
# --- Minimization Summary ---
# x_min is = [ 0.]
# f_min is = [ 0.]
# achieved tolerance = 0.0
# numFunctionCalls = 2
# ----------------------------

# %% [markdown]
# ### Numerical gradients

# %%
gd_numerical = GradientDescent(f)
gd_numerical.stepSize = 1e-2
x_0 = np.array([1.9])
gd_numerical.computeMin(x_0, useGradientCriterion=True, storeIterX=True, maxFunctionCalls=5000)

def plotWithDescent(gdObj):
    plt.plot(xaxis,yaxis_f, color ='blue')
    #plt.plot(xaxis,yaxis_grad, color='red')
    numIter = (gdObj.numIterations-1)
    plt.plot(gdObj.iterX[0:numIter], f(gdObj.iterX)[0:numIter], marker='x',color='black')
    plt.scatter(gdObj.iterX[0], f(gdObj.iterX)[0], marker='x', s=100, color='red')
    plt.scatter(gdObj.iterX[numIter], f(gdObj.iterX)[numIter], marker='x', s=100, color='green')
    plt.axis([-2, 2, -2, 3])
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.show()

plotWithDescent(gd_numerical)
    
x_0 = np.array([-1.0])
gd_numerical.computeMin(x_0, useGradientCriterion=True, storeIterX=True, maxFunctionCalls=5000)

plotWithDescent(gd_numerical)

x_0 = np.array([0.0])
gd_numerical.computeMin(x_0, useGradientCriterion=True, storeIterX=True, maxFunctionCalls=5000)

plotWithDescent(gd_numerical)
# Out:
#
# --- Minimization Summary ---
# x_min is = [ 1.17540341]
# f_min is = [-1.09673456]
# achieved tolerance = 9.69637259374e-05
# numFunctionCalls = 646
# ----------------------------
#
# --- Minimization Summary ---
# x_min is = [-0.4254267]
# f_min is = [-0.07123419]
# achieved tolerance = 9.85454134961e-05
# numFunctionCalls = 1556
# ----------------------------
#
# --- Minimization Summary ---
# x_min is = [  2.50000000e-13]
# f_min is = [ -6.25000000e-26]
# achieved tolerance = 2.54999999995e-11
# numFunctionCalls = 6
# ----------------------------

# %% [markdown]
# ### Scipy optimize

# %%
import scipy.optimize as opt

def SciOpt(x_0):
    res = opt.minimize(f, x_0)
    print " "
    print "--- Scipy Minimization Summary --- "
    print "x_0 is = " + str(x_0)
    print "x_min is = " + str(res.x)
    print "f_min is = " + str(res.fun)
    print "numFunctionCalls = " + str(res.nfev)
    print "---------------------------- "
    print " "

x_0 = np.array([1.9]); SciOpt(x_0)
x_0 = np.array([-1.0]); SciOpt(x_0)
x_0 = np.array([0.0]); SciOpt(x_0)
# Out:
#
# --- Scipy Minimization Summary ---
# x_0 is = [ 1.9]
# x_min is = [-0.42539037]
# f_min is = -0.0712341919243
# numFunctionCalls = 24
# ----------------------------
#
#
# --- Scipy Minimization Summary ---
# x_0 is = [-1.]
# x_min is = [ 1.17539051]
# f_min is = -1.09673455808
# numFunctionCalls = 36
# ----------------------------
#
#
# --- Scipy Minimization Summary ---
# x_0 is = [ 0.]
# x_min is = [ 0.]
# f_min is = [ 0.]
# numFunctionCalls = 3
# ----------------------------

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
from matplotlib.mlab import bivariate_normal
import matplotlib.pyplot as plt

matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'

cov = np.array([[1,0.4],
                [0.4,1]])
mean = np.array([0,0.5])

delta = 0.025
x = np.arange(-5.0, 5.0, delta)
y = np.arange(-2.0, 4.0, delta)
X, Y = np.meshgrid(x, y)

def negBivariateNormal(x):
    return -100 * bivariate_normal(x[0],x[1], cov[0,0], cov[1,1], mean[0], mean[1], cov[0,1])

Z = -100*bivariate_normal(X, Y, cov[0,0], cov[1,1], mean[0], mean[1], cov[0,1])


# Create a simple contour plot with labels using default colors.  The
# inline argument to clabel will control whether the labels are draw
# over the line segments of the contour, removing the lines beneath
# the label
plt.figure()
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
plt.title('Simplest default with labels')
plt.show()





def plotWithDescent(gdObj, plotTitle):
    plt.figure()
    CS = plt.contour(X, Y, Z)
    plt.clabel(CS, inline=1, fontsize=10)
    plt.title(plotTitle)
    #plt.plot(xaxis,yaxis_grad, color='red')
    numIter = (gdObj.numIterations-1)
    plt.plot(gdObj.iterX[0:numIter,0], gdObj.iterX[0:numIter,1], marker='x', color='black')
    plt.scatter(gdObj.iterX[0,0], gdObj.iterX[0,1], marker='x', s=100, color='red')
    plt.scatter(gdObj.iterX[numIter,0], gdObj.iterX[numIter,1], marker='x', s=100, color='green')
    plt.axis([-4, 4, -2, 3])
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.show()

gd2 = GradientDescent(negBivariateNormal)
gd2.stepSize = 1e-2
gd2.tol = 1e-9
x_0 = np.array([1,1])
gd2.computeMin(x_0, maxFunctionCalls=5000, useGradientCriterion=True, storeIterX=True,)
plotWithDescent(gd2, "Adequate step size")
    
gd2 = GradientDescent(negBivariateNormal)
gd2.stepSize = 0.2
gd2.tol = 1e-9
x_0 = np.array([1,1])
gd2.computeMin(x_0, maxFunctionCalls=5000, useGradientCriterion=True, storeIterX=True,)
plotWithDescent(gd2, "Too large step size")
# Out:
#
# --- Minimization Summary ---
# x_min is = [  7.69375674e-11   5.00000000e-01]
# f_min is = -17.3652279511
# achieved tolerance = 7.1054273576e-10
# numFunctionCalls = 1585
# ----------------------------
# WARNING: hit maximum number of function calls
#
# --- Minimization Summary ---
# x_min is = [-0.91449248  1.41449248]
# f_min is = -4.30872626499
# achieved tolerance = 6.56716292164
# numFunctionCalls = 5005
# ----------------------------

# %%
import math
cov = np.array([[1,0.4],
                [0.4,1]])
mean = np.array([0,0.5])

delta = 0.025
x = np.arange(-5.0, 5.0, delta)
y = np.arange(-2.0, 4.0, delta)
X, Y = np.meshgrid(x, y)

Z = -100*bivariate_normal(X, Y, cov[0,0], cov[1,1], mean[0], mean[1], cov[0,1])

# Create a simple contour plot with labels using default colors.  The
# inline argument to clabel will control whether the labels are draw
# over the line segments of the contour, removing the lines beneath
# the label
plt.figure()
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
plt.axis([-4, 4, -2, 3])
plt.show()



def p_negBivariateNormal(x):
    cov = np.array([[1,0.4],
                [0.4,1]])
    mean = np.array([0,0.5])
    prefactor = 1.0 / math.sqrt((np.linalg.det(2 * math.pi*cov)))
    mu_diff =  np.matrix(x-mean).T
    expfactor = -1.0/2.0 * (mu_diff.T * np.matrix(cov).I * mu_diff)
    ans = -100*prefactor * np.exp(expfactor)
    return ans[0,0]

def p_negBivariateNormalGradient(x):
    #print "x pass into grad is " + str(x)
    if ~isinstance(x,np.ndarray):
        x = np.array(x)
    #print "x is now " + str(x)
    cov = np.array([[1,0.4],
                [0.4,1]])
    mean = np.array([0,0.5])
    p = p_negBivariateNormal(x)
    #print "p is then " + str(p)
    grad = -p*np.matrix(cov).I * np.matrix(x-mean).T
    return np.array(grad)
    

xx = np.arange(-5.0, 5.0, delta)
yy = np.arange(-2.0, 4.0, delta)
ZZ = np.zeros((len(xx), len(yy)))

for i in range(len(xx)):
    for j in range(len(yy)):
        ZZ[i, j] = p_negBivariateNormal(np.hstack((xx[i],yy[j])))

plt.figure()

CS = plt.contour(xx, yy, ZZ.T)
plt.clabel(CS, inline=1, fontsize=10)
plt.axis([-4, 4, -2, 3])
plt.show()

# %%
def plotWithDescentLin(gdObj, plotTitle):
    plt.figure()
    CS = plt.contour(xx, yy, ZZ.T)
    plt.clabel(CS, inline=1, fontsize=10)
    plt.title(plotTitle)
    #plt.plot(xaxis,yaxis_grad, color='red')
    numIter = (gdObj.numIterations-1)
    plt.plot(gdObj.iterX[0:numIter,0], gdObj.iterX[0:numIter,1], marker='x', color='black')
    plt.scatter(gdObj.iterX[0,0], gdObj.iterX[0,1], marker='x', s=100, color='red')
    plt.scatter(gdObj.iterX[numIter,0], gdObj.iterX[numIter,1], marker='x', s=100, color='green')
    plt.axis([-4, 4, -2, 3])
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.show()

gd = GradientDescent(p_negBivariateNormal)
gd.stepSize = 1e-2
gd.tol = 1e-9
x_0 = np.array([1,1])
gd.computeMin(x_0, maxFunctionCalls=5000, useGradientCriterion=True, storeIterValues=True,storeIterX=True,)
gd.plotIterValues()
plotWithDescentLin(gd, "Numerical gradient")

gd = GradientDescent(p_negBivariateNormal,grad=p_negBivariateNormalGradient)
gd.stepSize = 1e-2
gd.tol = 1e-9
x_0 = np.array([1,1])

print x_0
print gd.evalGradient(x_0)
print gd.gradDescentUpdate(x_0)

gd.computeMin(x_0, maxFunctionCalls=5000, useGradientCriterion=True, storeIterValues=True, storeIterX=True)
gd.plotIterValues()
plotWithDescentLin(gd, "Analytical gradient")
# Out:
#
# --- Minimization Summary ---
# x_min is = [  5.38449285e-11   5.00000000e-01]
# f_min is = -17.3652279511
# achieved tolerance = 7.1054273576e-10
# numFunctionCalls = 1603
# ----------------------------
# [1 1]
# [[ 9.97146255]
#  [ 1.24643282]]
# (array([[ 0.90028537,  0.98753567]]), -11.467861882799756)
#
# --- Minimization Summary ---
# x_min is = [[  7.67472588e-11   5.00000000e-01]]
# f_min is = -17.3652279511
# achieved tolerance = 9.5195294173e-10
# numFunctionCalls = 177
# ----------------------------

# %%
import scipy.optimize as opt
res = opt.minimize(p_negBivariateNormal, x_0)
print " "
print "--- Scipy Minimization Summary --- "
print "x_min is = " + str(res.x)
print "f_min is = " + str(res.fun)
print "numFunctionCalls = " + str(res.nfev)
print "---------------------------- "
print " "
# Out:
#
# --- Scipy Minimization Summary ---
# x_min is = [ -1.18117716e-08   4.99999994e-01]
# f_min is = -17.3652279511
# numFunctionCalls = 48
# ----------------------------

# %%
x = np.matrix(np.array([0,1,2]))
print type(x)
# Out:
# <class 'numpy.matrixlib.defmatrix.matrix'>
